# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low = -90.000, high = 90.000, size=1500)
lngs = np.random.uniform(low = -180.000, high = 180.000, size= 1500)
lats_lngs = zip(lats,lngs)
lats_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lats_lngs)

# %%
# Create a list for holding the cities.
cities=[]
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 594

# %%
# Import the requests library.
import requests
#import the API key
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=' +weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d78a06bc1326800fe16d9db3952b2fb3

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data=[]
# Print the beginning of the logging.
print('Beginning Data Retrieval           ')
print('-----------------------------------')

#create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i>=50):
        set_count +=1
        record_count =1
        time.sleep(60)
            
     # Create endpoint URL with each city.
    city_url = url +'&q=' + cities[i]
   # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------------
# Processing Record 1 of Set 1 | shingu
# Processing Record 2 of Set 1 | jamestown
# Processing Record 3 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 1 | marawi
# Processing Record 5 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 1 | upernavik
# Processing Record 7 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 1 | nicoya
# Processing Record 9 of Set 1 | kadoshkino
# Processing Record 10 of Set 1 | gamba
# Processing Record 11 of Set 1 | hilo
# Processing Record 12 of Set 1 | victoria
# Processing Record 13 of Set 1 | avarua
# Processing Record 14 of Set 1 | barrow
# Processing Record 15 of Set 1 | bluff
# Processing Record 16 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 1 | khatanga
# Processing Record 18 of Set 1 | amiens
# Processing Record 19 of Set 1 | broome
# Processing Record 20 of Set 1 | nikolskoye
# Processing Record 21 of Set 1 | lazaro cardenas
# Processing Record 22 of Set 1 | tiksi
# Processing Record 23 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 1 | dinsor
# City not found. Skipping...
# Processing Record 25 of Set 1 | hobart
# Processing Record 26 of Set 1 | vaini
# Processing Record 27 of Set 1 | sandnessjoen
# Processing Record 28 of Set 1 | arraial do cabo
# Processing Record 29 of Set 1 | rikitea
# Processing Record 30 of Set 1 | iskateley
# Processing Record 31 of Set 1 | carnarvon
# Processing Record 32 of Set 1 | bethel
# Processing Record 33 of Set 1 | kruisfontein
# Processing Record 34 of Set 1 | leningradskiy
# Processing Record 35 of Set 1 | georgetown
# Processing Record 36 of Set 1 | palana
# Processing Record 37 of Set 1 | manokwari
# Processing Record 38 of Set 1 | wukari
# Processing Record 39 of Set 1 | cape town
# Processing Record 40 of Set 1 | kapaa
# Processing Record 41 of Set 1 | pacific grove
# Processing Record 42 of Set 1 | yellowknife
# Processing Record 43 of Set 1 | rangpur
# Processing Record 44 of Set 1 | novikovo
# Processing Record 45 of Set 1 | bredasdorp
# Processing Record 46 of Set 1 | punta arenas
# Processing Record 47 of Set 1 | hasaki
# Processing Record 48 of Set 1 | hermanus
# Processing Record 49 of Set 1 | port elizabeth
# Processing Record 50 of Set 1 | burica
# City not found. Skipping...
# Processing Record 1 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 3 of Set 2 | karratha
# Processing Record 4 of Set 2 | inongo
# Processing Record 5 of Set 2 | longyearbyen
# Processing Record 6 of Set 2 | ixtapa
# Processing Record 7 of Set 2 | castro
# Processing Record 8 of Set 2 | port hedland
# Processing Record 9 of Set 2 | soyo
# Processing Record 10 of Set 2 | albany
# Processing Record 11 of Set 2 | saint george
# Processing Record 12 of Set 2 | mehamn
# Processing Record 13 of Set 2 | ushuaia
# Processing Record 14 of Set 2 | yerbogachen
# Processing Record 15 of Set 2 | tokur
# Processing Record 16 of Set 2 | henties bay
# Processing Record 17 of Set 2 | baoning
# Processing Record 18 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 19 of Set 2 | port augusta
# Processing Record 20 of Set 2 | rio gallegos
# Processing Record 21 of Set 2 | rodnykove
# Processing Record 22 of Set 2 | atuona
# Processing Record 23 of Set 2 | saint-jean-port-joli
# Processing Record 24 of Set 2 | puerto baquerizo moreno
# Processing Record 25 of Set 2 | mataura
# Processing Record 26 of Set 2 | rabak
# Processing Record 27 of Set 2 | souillac
# Processing Record 28 of Set 2 | los llanos de aridane
# Processing Record 29 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 2 | falmouth
# Processing Record 31 of Set 2 | narsaq
# Processing Record 32 of Set 2 | veraval
# Processing Record 33 of Set 2 | asau
# Processing Record 34 of Set 2 | camacari
# Processing Record 35 of Set 2 | faanui
# Processing Record 36 of Set 2 | ekuvukeni
# Processing Record 37 of Set 2 | naze
# Processing Record 38 of Set 2 | saint-philippe
# Processing Record 39 of Set 2 | sao paulo de olivenca
# Processing Record 40 of Set 2 | arauco
# Processing Record 41 of Set 2 | new norfolk
# Processing Record 42 of Set 2 | kahului
# Processing Record 43 of Set 2 | kamyshin
# Processing Record 44 of Set 2 | tahta
# Processing Record 45 of Set 2 | aksarka
# Processing Record 46 of Set 2 | bagdarin
# Processing Record 47 of Set 2 | saint-augustin
# Processing Record 48 of Set 2 | mar del plata
# Processing Record 49 of Set 2 | hithadhoo
# Processing Record 50 of Set 2 | koumac
# Processing Record 1 of Set 3 | challans
# Processing Record 2 of Set 3 | deputatskiy
# Processing Record 3 of Set 3 | novoaleksandrovsk
# Processing Record 4 of Set 3 | khani
# Processing Record 5 of Set 3 | chuy
# Processing Record 6 of Set 3 | esperance
# Processing Record 7 of Set 3 | tuktoyaktuk
# Processing Record 8 of Set 3 | tambacounda
# Processing Record 9 of Set 3 | thompson
# Processing Record 10 of Set 3 | voznesenskaya
# Processing Record 11 of Set 3 | kuldur
# Processing Record 12 of Set 3 | moses lake
# Processing Record 13 of Set 3 | whitehorse
# Processing Record 14 of Set 3 | hammerfest
# Processing Record 15 of Set 3 | komsomolskiy
# Processing Record 16 of Set 3 | palora
# Processing Record 17 of Set 3 | fukue
# Processing Record 18 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 19 of Set 3 | cabra
# Processing Record 20 of Set 3 | aklavik
# Processing Record 21 of Set 3 | sitka
# Processing Record 22 of Set 3 | ettenheim
# Processing Record 23 of Set 3 | beibei
# Processing Record 24 of Set 3 | kodiak
# Processing Record 25 of Set 3 | hambantota
# Processing Record 26 of Set 3 | santarem
# Processing Record 27 of Set 3 | cidreira
# Processing Record 28 of Set 3 | pasighat
# Processing Record 29 of Set 3 | boyabat
# Processing Record 30 of Set 3 | santa cruz
# Processing Record 31 of Set 3 | tateyama
# Processing Record 32 of Set 3 | vallenar
# Processing Record 33 of Set 3 | kupang
# Processing Record 34 of Set 3 | tolosa
# Processing Record 35 of Set 3 | clyde river
# Processing Record 36 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 3 | paradise
# Processing Record 38 of Set 3 | sola
# Processing Record 39 of Set 3 | busselton
# Processing Record 40 of Set 3 | namatanai
# Processing Record 41 of Set 3 | nanortalik
# Processing Record 42 of Set 3 | husavik
# Processing Record 43 of Set 3 | bambous virieux
# Processing Record 44 of Set 3 | angoche
# Processing Record 45 of Set 3 | dukat
# Processing Record 46 of Set 3 | muros
# Processing Record 47 of Set 3 | mingguang
# Processing Record 48 of Set 3 | breves
# Processing Record 49 of Set 3 | iqaluit
# Processing Record 50 of Set 3 | peniche
# Processing Record 1 of Set 4 | kota bahru
# Processing Record 2 of Set 4 | aranos
# Processing Record 3 of Set 4 | athens
# Processing Record 4 of Set 4 | faya
# Processing Record 5 of Set 4 | griffith
# Processing Record 6 of Set 4 | ouallam
# Processing Record 7 of Set 4 | saskylakh
# Processing Record 8 of Set 4 | mweka
# Processing Record 9 of Set 4 | qaanaaq
# Processing Record 10 of Set 4 | chengde
# Processing Record 11 of Set 4 | vestmannaeyjar
# Processing Record 12 of Set 4 | angouleme
# Processing Record 13 of Set 4 | benguela
# Processing Record 14 of Set 4 | salalah
# Processing Record 15 of Set 4 | pavia
# Processing Record 16 of Set 4 | pevek
# Processing Record 17 of Set 4 | puerto ayora
# Processing Record 18 of Set 4 | irbeyskoye
# Processing Record 19 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 4 | sarangani
# Processing Record 21 of Set 4 | pravdinsk
# Processing Record 22 of Set 4 | severo-kurilsk
# Processing Record 23 of Set 4 | stamsund
# City not found. Skipping...
# Processing Record 24 of Set 4 | la rioja
# Processing Record 25 of Set 4 | grindavik
# Processing Record 26 of Set 4 | lasa
# Processing Record 27 of Set 4 | virden
# Processing Record 28 of Set 4 | entre rios
# Processing Record 29 of Set 4 | dawlatabad
# Processing Record 30 of Set 4 | palma di montechiaro
# Processing Record 31 of Set 4 | sinnamary
# Processing Record 32 of Set 4 | adeje
# Processing Record 33 of Set 4 | batemans bay
# Processing Record 34 of Set 4 | wakkanai
# Processing Record 35 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 4 | eldikan
# City not found. Skipping...
# Processing Record 37 of Set 4 | north bend
# Processing Record 38 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 39 of Set 4 | owando
# Processing Record 40 of Set 4 | ponta do sol
# Processing Record 41 of Set 4 | nacozari
# Processing Record 42 of Set 4 | kaitangata
# Processing Record 43 of Set 4 | krasnoselkup
# Processing Record 44 of Set 4 | bucak
# Processing Record 45 of Set 4 | kurumkan
# Processing Record 46 of Set 4 | port lincoln
# Processing Record 47 of Set 4 | tasiilaq
# Processing Record 48 of Set 4 | sheridan
# Processing Record 49 of Set 4 | tessalit
# Processing Record 50 of Set 4 | dikson
# Processing Record 1 of Set 5 | bilma
# Processing Record 2 of Set 5 | tigil
# Processing Record 3 of Set 5 | manzanillo
# Processing Record 4 of Set 5 | markova
# Processing Record 5 of Set 5 | butaritari
# Processing Record 6 of Set 5 | ribeira grande
# Processing Record 7 of Set 5 | san patricio
# Processing Record 8 of Set 5 | port alfred
# Processing Record 9 of Set 5 | phan thiet
# Processing Record 10 of Set 5 | dzilam gonzalez
# Processing Record 11 of Set 5 | jiayuguan
# Processing Record 12 of Set 5 | zhigansk
# Processing Record 13 of Set 5 | meulaboh
# Processing Record 14 of Set 5 | pedernales
# Processing Record 15 of Set 5 | cayenne
# Processing Record 16 of Set 5 | yarmouth
# Processing Record 17 of Set 5 | kolpashevo
# Processing Record 18 of Set 5 | fairbanks
# Processing Record 19 of Set 5 | balkanabat
# Processing Record 20 of Set 5 | coihaique
# Processing Record 21 of Set 5 | corinto
# Processing Record 22 of Set 5 | taltal
# Processing Record 23 of Set 5 | sept-iles
# Processing Record 24 of Set 5 | houston
# Processing Record 25 of Set 5 | maceio
# Processing Record 26 of Set 5 | kavieng
# Processing Record 27 of Set 5 | sukhumi
# Processing Record 28 of Set 5 | inhambane
# Processing Record 29 of Set 5 | antalaha
# Processing Record 30 of Set 5 | fort saint john
# City not found. Skipping...
# Processing Record 31 of Set 5 | athabasca
# Processing Record 32 of Set 5 | itarema
# Processing Record 33 of Set 5 | cortez
# Processing Record 34 of Set 5 | kununurra
# Processing Record 35 of Set 5 | ancud
# Processing Record 36 of Set 5 | playas
# Processing Record 37 of Set 5 | pangody
# Processing Record 38 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 39 of Set 5 | praia da vitoria
# Processing Record 40 of Set 5 | bolshiye uki
# City not found. Skipping...
# Processing Record 41 of Set 5 | thinadhoo
# Processing Record 42 of Set 5 | ondorhaan
# City not found. Skipping...
# Processing Record 43 of Set 5 | casablanca
# Processing Record 44 of Set 5 | east london
# Processing Record 45 of Set 5 | guaraniacu
# Processing Record 46 of Set 5 | namibe
# Processing Record 47 of Set 5 | arrecife
# Processing Record 48 of Set 5 | klaksvik
# Processing Record 49 of Set 5 | huarmey
# Processing Record 50 of Set 5 | andarab
# City not found. Skipping...
# Processing Record 1 of Set 6 | shelburne
# Processing Record 2 of Set 6 | port macquarie
# Processing Record 3 of Set 6 | campos novos
# Processing Record 4 of Set 6 | samarai
# Processing Record 5 of Set 6 | mahebourg
# Processing Record 6 of Set 6 | zhuanghe
# Processing Record 7 of Set 6 | sao raimundo das mangabeiras
# Processing Record 8 of Set 6 | olinda
# Processing Record 9 of Set 6 | ornskoldsvik
# Processing Record 10 of Set 6 | yulara
# Processing Record 11 of Set 6 | saint-francois
# Processing Record 12 of Set 6 | guerrero negro
# Processing Record 13 of Set 6 | riverton
# Processing Record 14 of Set 6 | lodja
# Processing Record 15 of Set 6 | saint-pierre
# Processing Record 16 of Set 6 | sao filipe
# Processing Record 17 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 18 of Set 6 | la ronge
# Processing Record 19 of Set 6 | taoudenni
# Processing Record 20 of Set 6 | taguatinga
# Processing Record 21 of Set 6 | mount gambier
# Processing Record 22 of Set 6 | harrisonville
# Processing Record 23 of Set 6 | hailar
# Processing Record 24 of Set 6 | lata
# Processing Record 25 of Set 6 | talaya
# Processing Record 26 of Set 6 | conceicao do araguaia
# Processing Record 27 of Set 6 | sakhnovshchyna
# Processing Record 28 of Set 6 | dauriya
# Processing Record 29 of Set 6 | pochutla
# Processing Record 30 of Set 6 | naruto
# Processing Record 31 of Set 6 | hualmay
# Processing Record 32 of Set 6 | dunedin
# Processing Record 33 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 6 | mandera
# Processing Record 35 of Set 6 | torbay
# Processing Record 36 of Set 6 | hamilton
# Processing Record 37 of Set 6 | kalmunai
# Processing Record 38 of Set 6 | togur
# Processing Record 39 of Set 6 | saldanha
# Processing Record 40 of Set 6 | winnemucca
# Processing Record 41 of Set 6 | ketchikan
# Processing Record 42 of Set 6 | west wendover
# Processing Record 43 of Set 6 | quelimane
# Processing Record 44 of Set 6 | anamur
# Processing Record 45 of Set 6 | cagli
# Processing Record 46 of Set 6 | buariki
# City not found. Skipping...
# Processing Record 47 of Set 6 | roseburg
# Processing Record 48 of Set 6 | nuuk
# Processing Record 49 of Set 6 | bengkulu
# Processing Record 50 of Set 6 | sioux lookout
# Processing Record 1 of Set 7 | beringovskiy
# Processing Record 2 of Set 7 | melilla
# Processing Record 3 of Set 7 | frutigen
# Processing Record 4 of Set 7 | lavrentiya
# Processing Record 5 of Set 7 | lircay
# Processing Record 6 of Set 7 | stuttgart
# Processing Record 7 of Set 7 | rockhampton
# Processing Record 8 of Set 7 | chokurdakh
# Processing Record 9 of Set 7 | kayes
# Processing Record 10 of Set 7 | college
# Processing Record 11 of Set 7 | bathsheba
# Processing Record 12 of Set 7 | surany
# Processing Record 13 of Set 7 | rolim de moura
# City not found. Skipping...
# Processing Record 14 of Set 7 | provideniya
# Processing Record 15 of Set 7 | puerto el triunfo
# Processing Record 16 of Set 7 | tura
# Processing Record 17 of Set 7 | adrar
# Processing Record 18 of Set 7 | bocaranga
# City not found. Skipping...
# Processing Record 19 of Set 7 | nishihara
# Processing Record 20 of Set 7 | kyabram
# Processing Record 21 of Set 7 | roald
# Processing Record 22 of Set 7 | tahe
# Processing Record 23 of Set 7 | vila franca do campo
# Processing Record 24 of Set 7 | jabiru
# City not found. Skipping...
# Processing Record 25 of Set 7 | minna
# Processing Record 26 of Set 7 | carutapera
# Processing Record 27 of Set 7 | tiznit
# Processing Record 28 of Set 7 | port moresby
# Processing Record 29 of Set 7 | longlac
# City not found. Skipping...
# Processing Record 30 of Set 7 | hervey bay
# Processing Record 31 of Set 7 | pisco
# Processing Record 32 of Set 7 | puerto maldonado
# Processing Record 33 of Set 7 | loralai
# Processing Record 34 of Set 7 | katiola
# Processing Record 35 of Set 7 | soe
# Processing Record 36 of Set 7 | do rud
# City not found. Skipping...
# Processing Record 37 of Set 7 | sabang
# Processing Record 38 of Set 7 | lorengau
# Processing Record 39 of Set 7 | alice springs
# Processing Record 40 of Set 7 | hami
# Processing Record 41 of Set 7 | norman wells
# Processing Record 42 of Set 7 | katobu
# Processing Record 43 of Set 7 | praya
# Processing Record 44 of Set 7 | turukhansk
# Processing Record 45 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 46 of Set 7 | lompoc
# Processing Record 47 of Set 7 | vao
# Processing Record 48 of Set 7 | volchikha
# Processing Record 49 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 50 of Set 7 | madison heights
# Processing Record 1 of Set 8 | marv dasht
# City not found. Skipping...
# Processing Record 2 of Set 8 | les cayes
# Processing Record 3 of Set 8 | monte alegre
# Processing Record 4 of Set 8 | sur
# Processing Record 5 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 6 of Set 8 | sedalia
# Processing Record 7 of Set 8 | sao joao da barra
# Processing Record 8 of Set 8 | zheleznodorozhnyy
# Processing Record 9 of Set 8 | takoradi
# Processing Record 10 of Set 8 | buala
# Processing Record 11 of Set 8 | bubaque
# Processing Record 12 of Set 8 | panuco
# Processing Record 13 of Set 8 | port keats
# Processing Record 14 of Set 8 | fort nelson
# Processing Record 15 of Set 8 | san luis
# Processing Record 16 of Set 8 | waipawa
# Processing Record 17 of Set 8 | tuatapere
# Processing Record 18 of Set 8 | voi
# Processing Record 19 of Set 8 | geraldton
# Processing Record 20 of Set 8 | srednekolymsk
# Processing Record 21 of Set 8 | duluth
# Processing Record 22 of Set 8 | gizo
# Processing Record 23 of Set 8 | mangrol
# Processing Record 24 of Set 8 | ambodifototra
# City not found. Skipping...
# Processing Record 25 of Set 8 | cuiaba
# Processing Record 26 of Set 8 | isetskoye
# Processing Record 27 of Set 8 | paamiut
# Processing Record 28 of Set 8 | coffs harbour
# Processing Record 29 of Set 8 | rusca montana
# City not found. Skipping...
# Processing Record 30 of Set 8 | hunza
# City not found. Skipping...
# Processing Record 31 of Set 8 | skjervoy
# Processing Record 32 of Set 8 | ha giang
# Processing Record 33 of Set 8 | mamontovo
# Processing Record 34 of Set 8 | sunam
# Processing Record 35 of Set 8 | chumikan
# Processing Record 36 of Set 8 | eyl
# Processing Record 37 of Set 8 | sorong
# Processing Record 38 of Set 8 | police
# Processing Record 39 of Set 8 | morros
# Processing Record 40 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 41 of Set 8 | lebu
# Processing Record 42 of Set 8 | yuci
# Processing Record 43 of Set 8 | klyuchi
# Processing Record 44 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 45 of Set 8 | mount isa
# Processing Record 46 of Set 8 | gedo
# Processing Record 47 of Set 8 | gilgil
# City not found. Skipping...
# Processing Record 48 of Set 8 | darlowo
# Processing Record 49 of Set 8 | lamesa
# Processing Record 50 of Set 8 | omboue
# Processing Record 1 of Set 9 | burkhala
# City not found. Skipping...
# Processing Record 2 of Set 9 | paro
# Processing Record 3 of Set 9 | tutoia
# Processing Record 4 of Set 9 | okhotsk
# Processing Record 5 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 9 | tautira
# Processing Record 7 of Set 9 | ahuimanu
# Processing Record 8 of Set 9 | kavaratti
# Processing Record 9 of Set 9 | talnakh
# Processing Record 10 of Set 9 | boa vista
# Processing Record 11 of Set 9 | kautokeino
# Processing Record 12 of Set 9 | abu samrah
# Processing Record 13 of Set 9 | churapcha
# Processing Record 14 of Set 9 | scottsburgh
# City not found. Skipping...
# Processing Record 15 of Set 9 | luanda
# Processing Record 16 of Set 9 | finschhafen
# Processing Record 17 of Set 9 | zapolyarnyy
# Processing Record 18 of Set 9 | matameye
# City not found. Skipping...
# Processing Record 19 of Set 9 | boralday
# Processing Record 20 of Set 9 | gopalpur
# Processing Record 21 of Set 9 | kongolo
# Processing Record 22 of Set 9 | nome
# Processing Record 23 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 24 of Set 9 | buraydah
# Processing Record 25 of Set 9 | luderitz
# Processing Record 26 of Set 9 | portland
# Processing Record 27 of Set 9 | ambilobe
# Processing Record 28 of Set 9 | bilibino
# Processing Record 29 of Set 9 | bairiki
# Processing Record 30 of Set 9 | coahuayana
# Processing Record 31 of Set 9 | clarence town
# Processing Record 32 of Set 9 | atar
# Processing Record 33 of Set 9 | trelew
# Processing Record 34 of Set 9 | mikhaylovka
# Processing Record 35 of Set 9 | yinchuan
# Processing Record 36 of Set 9 | kamphaeng phet
# Processing Record 37 of Set 9 | vavoua
# Processing Record 38 of Set 9 | mungwi
# Processing Record 39 of Set 9 | ilulissat
# Processing Record 40 of Set 9 | esso
# Processing Record 41 of Set 9 | severo-yeniseyskiy
# Processing Record 42 of Set 9 | marsh harbour
# Processing Record 43 of Set 9 | dickinson
# Processing Record 44 of Set 9 | chernyshevskiy
# Processing Record 45 of Set 9 | asfi
# Processing Record 46 of Set 9 | makakilo city
# Processing Record 47 of Set 9 | miguel hidalgo
# Processing Record 48 of Set 9 | airai
# Processing Record 49 of Set 9 | yanan
# City not found. Skipping...
# Processing Record 50 of Set 9 | miandoab
# Processing Record 1 of Set 10 | cabo san lucas
# Processing Record 2 of Set 10 | kilrush
# Processing Record 3 of Set 10 | puerto narino
# Processing Record 4 of Set 10 | altamont
# Processing Record 5 of Set 10 | quatre cocos
# Processing Record 6 of Set 10 | gwadar
# Processing Record 7 of Set 10 | rochegda
# Processing Record 8 of Set 10 | phangnga
# Processing Record 9 of Set 10 | broken hill
# Processing Record 10 of Set 10 | omsukchan
# Processing Record 11 of Set 10 | ibra
# Processing Record 12 of Set 10 | nortelandia
# Processing Record 13 of Set 10 | riviere-au-renard
# Processing Record 14 of Set 10 | salta
# Processing Record 15 of Set 10 | ngama
# Processing Record 16 of Set 10 | vila nova de milfontes
# Processing Record 17 of Set 10 | bambari
# Processing Record 18 of Set 10 | amberg
# Processing Record 19 of Set 10 | yablochnyy
# Processing Record 20 of Set 10 | wajir
# Processing Record 21 of Set 10 | erzin
# Processing Record 22 of Set 10 | labuhan
# Processing Record 23 of Set 10 | florianopolis
# Processing Record 24 of Set 10 | hofn
# Processing Record 25 of Set 10 | haines junction
# Processing Record 26 of Set 10 | nioro
# Processing Record 27 of Set 10 | japura
# Processing Record 28 of Set 10 | davila
# Processing Record 29 of Set 10 | kenora
# Processing Record 30 of Set 10 | kailua
# Processing Record 31 of Set 10 | lonar
# Processing Record 32 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 33 of Set 10 | falealupo
# City not found. Skipping...
# Processing Record 34 of Set 10 | holetown
# Processing Record 35 of Set 10 | mandalgovi
# Processing Record 36 of Set 10 | berlevag
# Processing Record 37 of Set 10 | teruel
# Processing Record 38 of Set 10 | roura
# Processing Record 39 of Set 10 | caravelas
# Processing Record 40 of Set 10 | mareeba
# Processing Record 41 of Set 10 | katsiveli
# City not found. Skipping...
# Processing Record 42 of Set 10 | armidale
# Processing Record 43 of Set 10 | katsuura
# Processing Record 44 of Set 10 | cockburn town
# Processing Record 45 of Set 10 | kulhudhuffushi
# Processing Record 46 of Set 10 | cherskiy
# Processing Record 47 of Set 10 | camacha
# Processing Record 48 of Set 10 | smidovich
# Processing Record 49 of Set 10 | sao jose da coroa grande
# Processing Record 50 of Set 10 | qiryat shemona
# Processing Record 1 of Set 11 | waimana
# Processing Record 2 of Set 11 | san rafael
# Processing Record 3 of Set 11 | katherine
# Processing Record 4 of Set 11 | odweyne
# Processing Record 5 of Set 11 | oneonta
# Processing Record 6 of Set 11 | patnos
# Processing Record 7 of Set 11 | panjab
# Processing Record 8 of Set 11 | ouadda
# Processing Record 9 of Set 11 | saint-denis
# Processing Record 10 of Set 11 | carmen
# Processing Record 11 of Set 11 | svetlogorsk
# Processing Record 12 of Set 11 | dumas
# Processing Record 13 of Set 11 | tuy hoa
# Processing Record 14 of Set 11 | egvekinot
# Processing Record 15 of Set 11 | santa fe
# Processing Record 16 of Set 11 | belaya gora
# Processing Record 17 of Set 11 | yenagoa
# Processing Record 18 of Set 11 | surok
# Processing Record 19 of Set 11 | fonte boa
# Processing Record 20 of Set 11 | itamaraca
# Processing Record 21 of Set 11 | nipawin
# Processing Record 22 of Set 11 | amapa
# Processing Record 23 of Set 11 | vila do maio
# Processing Record 24 of Set 11 | port hardy
# Processing Record 25 of Set 11 | victoria point
# Processing Record 26 of Set 11 | sorland
# Processing Record 27 of Set 11 | nekhayevskiy
# Processing Record 28 of Set 11 | pouebo
# Processing Record 29 of Set 11 | changli
# Processing Record 30 of Set 11 | tommot
# Processing Record 31 of Set 11 | ario
# City not found. Skipping...
# Processing Record 32 of Set 11 | kinkala
# Processing Record 33 of Set 11 | payo
# Processing Record 34 of Set 11 | laramie
# Processing Record 35 of Set 11 | sucua
# Processing Record 36 of Set 11 | baghdad
# Processing Record 37 of Set 11 | yima
# Processing Record 38 of Set 11 | beira
# Processing Record 39 of Set 11 | piranhas
# Processing Record 40 of Set 11 | riyadh
# Processing Record 41 of Set 11 | codrington
# Processing Record 42 of Set 11 | yialos
# City not found. Skipping...
# Processing Record 43 of Set 11 | sulangan
# Processing Record 44 of Set 11 | nikel
# Processing Record 45 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 46 of Set 11 | yamethin
# Processing Record 47 of Set 11 | cedar city
# Processing Record 48 of Set 11 | vidim
# Processing Record 49 of Set 11 | ngunguru
# Processing Record 50 of Set 11 | coquimbo
# Processing Record 1 of Set 12 | canitas
# City not found. Skipping...
# Processing Record 2 of Set 12 | mallaig
# Processing Record 3 of Set 12 | rio claro
# Processing Record 4 of Set 12 | bowling green
# Processing Record 5 of Set 12 | iisalmi
# Processing Record 6 of Set 12 | grand-santi
# Processing Record 7 of Set 12 | matara
# Processing Record 8 of Set 12 | isabela
# Processing Record 9 of Set 12 | touros
# Processing Record 10 of Set 12 | khormuj
# City not found. Skipping...
# Processing Record 11 of Set 12 | rawson
# Processing Record 12 of Set 12 | brae
# Processing Record 13 of Set 12 | lima
# Processing Record 14 of Set 12 | zyryanka
# Processing Record 15 of Set 12 | byron bay
# Processing Record 16 of Set 12 | dingle
# Processing Record 17 of Set 12 | villamontes
# Processing Record 18 of Set 12 | bedesa
# Processing Record 19 of Set 12 | juarez
# Processing Record 20 of Set 12 | biak
# Processing Record 21 of Set 12 | kenai
# Processing Record 22 of Set 12 | anadyr
# Processing Record 23 of Set 12 | cap malheureux
# Processing Record 24 of Set 12 | ati
# Processing Record 25 of Set 12 | banda
# Processing Record 26 of Set 12 | paramonga
# Processing Record 27 of Set 12 | hudson bay
# Processing Record 28 of Set 12 | windhoek
# Processing Record 29 of Set 12 | jahrom
# City not found. Skipping...
# Processing Record 30 of Set 12 | waingapu
# Processing Record 31 of Set 12 | moundsville
# Processing Record 32 of Set 12 | tongliao
# Processing Record 33 of Set 12 | araouane
# Processing Record 34 of Set 12 | pineville
# Processing Record 35 of Set 12 | keti bandar
# Processing Record 36 of Set 12 | tabou
# Processing Record 37 of Set 12 | uruzgan
# Processing Record 38 of Set 12 | morondava
# Processing Record 39 of Set 12 | navahrudak
# Processing Record 40 of Set 12 | wellington
# Processing Record 41 of Set 12 | sechura
# Processing Record 42 of Set 12 | sungaipenuh
# Processing Record 43 of Set 12 | houlung
# City not found. Skipping...
# Processing Record 44 of Set 12 | evensk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 538

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Shingu  33.7333  135.9833     38.91        64          19        5.57
# 1   Jamestown  42.0970  -79.2353     33.39        44           0        7.00
# 2      Marawi   7.9986  124.2928     64.65        88          26        1.52
# 3   Upernavik  72.7868  -56.1549    -15.50        99         100        9.75
# 4      Nicoya  10.1483  -85.4520     83.75        47          73        9.26
# 5  Kadoshkino  54.0257   44.4191     10.18        97          98        5.91
# 6       Gamba  -2.6500   10.0000     76.68        89          29        5.77
# 7        Hilo  19.7297 -155.0900     74.25        93          53        3.00
# 8    Victoria  22.2855  114.1577     61.25        87         100        8.99
# 9      Avarua -21.2078 -159.7750     82.45        78          40       16.11
#
#   Country                 Date
# 0      JP  2022-02-06 23:11:59
# 1      US  2022-02-06 23:08:28
# 2      PH  2022-02-06 23:08:11
# 3      GL  2022-02-06 23:08:20
# 4      CR  2022-02-06 23:12:00
# 5      RU  2022-02-06 23:12:00
# 6      GA  2022-02-06 23:09:32
# 7      US  2022-02-06 23:04:17
# 8      HK  2022-02-06 23:07:56
# 9      CK  2022-02-06 23:12:01

# %%
new_coloumn_order= ['City', 'Country', 'Date', 'Lat','Lng' ,'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed']
city_data_df = city_data_df[new_coloumn_order]
city_data_df.head(20)
# Out:
#                City Country                 Date      Lat       Lng  Max Temp  \
# 0            Shingu      JP  2022-02-06 23:11:59  33.7333  135.9833     38.91
# 1         Jamestown      US  2022-02-06 23:08:28  42.0970  -79.2353     33.39
# 2            Marawi      PH  2022-02-06 23:08:11   7.9986  124.2928     64.65
# 3         Upernavik      GL  2022-02-06 23:08:20  72.7868  -56.1549    -15.50
# 4            Nicoya      CR  2022-02-06 23:12:00  10.1483  -85.4520     83.75
# 5        Kadoshkino      RU  2022-02-06 23:12:00  54.0257   44.4191     10.18
# 6             Gamba      GA  2022-02-06 23:09:32  -2.6500   10.0000     76.68
# 7              Hilo      US  2022-02-06 23:04:17  19.7297 -155.0900     74.25
# 8          Victoria      HK  2022-02-06 23:07:56  22.2855  114.1577     61.25
# 9            Avarua      CK  2022-02-06 23:12:01 -21.2078 -159.7750     82.45
# 10           Barrow      US  2022-02-06 23:07:15  71.2906 -156.7887    -25.58
# 11            Bluff      NZ  2022-02-06 23:06:44 -46.6000  168.3333     58.80
# 12         Khatanga      RU  2022-02-06 23:08:06  71.9667  102.5000    -16.06
# 13           Amiens      FR  2022-02-06 23:12:02  49.9000    2.3000     47.26
# 14           Broome      US  2022-02-06 23:11:25  42.2506  -75.8330     26.06
# 15       Nikolskoye      RU  2022-02-06 23:07:10  59.7035   30.7861     35.87
# 16  Lazaro Cardenas      MX  2022-02-06 23:12:02  17.9583 -102.2000     82.89
# 17            Tiksi      RU  2022-02-06 23:03:42  71.6872  128.8694    -15.56
# 18           Hobart      AU  2022-02-06 23:07:15 -42.8794  147.3294     70.02
# 19            Vaini      TO  2022-02-06 23:08:18 -21.2000 -175.2000     77.16
#
#     Humidity  Cloudiness  Wind Speed
# 0         64          19        5.57
# 1         44           0        7.00
# 2         88          26        1.52
# 3         99         100        9.75
# 4         47          73        9.26
# 5         97          98        5.91
# 6         89          29        5.77
# 7         93          53        3.00
# 8         87         100        8.99
# 9         78          40       16.11
# 10        68           0       12.66
# 11        61           1        9.66
# 12        98          99        9.06
# 13        75          52       22.77
# 14        73           0        1.99
# 15        94         100       11.43
# 16        51           9       10.58
# 17        99         100        5.03
# 18        58          20        3.00
# 19        94         100       11.50

# %%
# Create the output file (CSV).
output_data_file = 'weather_data/cities.csv'
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label = 'City_ID')

# %%
# Extract relevant fields from the DataFrame for plotting.
lats= city_data_df['Lat']
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the # Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats, max_temps, edgecolor ='black', linewidths=1, marker='o', alpha=0.8, label='Cities')

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the # Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats, humidity, edgecolor ='black', linewidths=1, marker='o', alpha=0.8, label='Cities')

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the # Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats, cloudiness, edgecolor ='black', linewidths=1, marker='o', alpha=0.8, label='Cities')

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the # Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats, wind_speed, edgecolor ='black', linewidths=1, marker='o', alpha=0.8, label='Cities')

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel(" Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.

def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    # Run regression on hemisphere weather data
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
     
    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    
    # Get the equation of the line.
    line_eq = 'y =' + str(round(slope,2))+ 'x +' +str(round(intercept,2))

    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, 'r')
    
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color='red')
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show

# %%
index13= city_data_df.loc[13]
index13
# Out:
# City                       Amiens
# Country                        FR
# Date          2022-02-06 23:12:02
# Lat                          49.9
# Lng                           2.3
# Max Temp                    47.26
# Humidity                       75
# Cloudiness                     52
# Wind Speed                  22.77
# Name: 13, dtype: object

# %%
city_data_df["Lat"] >= 0
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 533     True
# 534    False
# 535    False
# 536    False
# 537     True
# Name: Lat, Length: 538, dtype: bool

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)].head()
# Out:
#         City Country                 Date      Lat       Lng  Max Temp  \
# 0     Shingu      JP  2022-02-06 23:11:59  33.7333  135.9833     38.91
# 1  Jamestown      US  2022-02-06 23:08:28  42.0970  -79.2353     33.39
# 2     Marawi      PH  2022-02-06 23:08:11   7.9986  124.2928     64.65
# 3  Upernavik      GL  2022-02-06 23:08:20  72.7868  -56.1549    -15.50
# 4     Nicoya      CR  2022-02-06 23:12:00  10.1483  -85.4520     83.75
#
#    Humidity  Cloudiness  Wind Speed
# 0        64          19        5.57
# 1        44           0        7.00
# 2        88          26        1.52
# 3        99         100        9.75
# 4        47          73        9.26

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df= city_data_df.loc[(city_data_df['Lat']>=0)]
southern_hemi_df= city_data_df.loc[(city_data_df['Lat']< 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

# Call the function.
plot_linear_regression(x_values, y_values, 
                       'Linear Regression on the Northern Hemisphere \n for Maximum Temperature','Max Temp', (10,-40))

# %%
# Linear regression on the Southeren Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]

# Call the function.
plot_linear_regression(x_values, y_values, 
                       'Linear Regression on the Southeren Hemisphere \n for Maximum Temperature','Max Temp', (-50,50))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']
# Call the function
plot_linear_regression(x_values, y_values, 'Linear Regression on the Northern Hemisphere \n for % Humidity',
                       '% Humidity', (47,10))

# %%
# Linear regression on the Northern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']
# Call the function
plot_linear_regression(x_values, y_values, 'Linear Regression on the southern Hemisphere \n for % Humidity',
                       '% Humidity', (-25,25))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']
# Call the function
plot_linear_regression(x_values, y_values, 'Linear Regression on the Northern Hemisphere \n for % Cloudiness',
                       '% Cloudiness',(1,29))

# %%
# Linear regression on the Northern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']
# Call the function
plot_linear_regression(x_values, y_values, 'Linear Regression on the southern Hemisphere \n for % Cloudiness',
                       '% Cloudiness', (-55,80))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']
# Call the function
plot_linear_regression(x_values, y_values, 'Linear Regression on the Northern Hemisphere \n for Wind Speed (mph)',
                       'Wind Speed (mph)',(1,29))

# %%
# Linear regression on the Northern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']
# Call the function
plot_linear_regression(x_values, y_values, 'Linear Regression on the southern Hemisphere \n for Wind Speed (mph)',
                       'Wind Speed(mph)', (-22,25))
